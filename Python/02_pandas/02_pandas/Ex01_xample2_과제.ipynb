# %% [markdown]
# ## [예제] 미국 대통령 당선 정보에서 정당 정보를 도출하여 시각하 하기
#
#
# ### * 불러온 데이타집합의 정보 확인하기
#
# - type(df)  : 데이타 타입
# - df.shape  : 행과 열의 수
# - df.columns : 컬럼명 확인
# - df.dtypes : 각각의 컬럼 데이타타입
# - df.info() : df.dtypes 비슷
# - df.info
# - df.head()
# - df.tail()
#
#
# ### 파이썬과 판다스 자료형 비교
#     int         int64
#     float       float64
#     string      object(****)
#
# ###  당선된 각 정당(Political Party) 수를 먼저 구해야 한다
#
# - value_counts() 이용
#
# ### [조별과제] 데이타셋에서 다른 인사이트를 도출하여 시각화하기

# %%
import pandas as pd

# %%
df = pd.read_excel('http://qrc.depaul.edu/excel_files/presidents.xlsx')
df        # 결과에 보면 NA() 결측치 보임
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
###  데이타 정보 확인하기
'''
- print(type(df))  # 데이타 타입
- print(df.shape) # 행과 열의 수
- print(df.columns) # 컬럼명 확인
- print(df.dtypes) # 각각의 컬럼 데이타타입
- print(df.info()) # df.dtypes 비슷
- print(df.info) # 전체적인 내용을???
- print(df.head())
- print(df.tail())
'''
# Out:
# '\n- print(type(df))  # 데이타 타입\n- print(df.shape) # 행과 열의 수\n- print(df.columns) # 컬럼명 확인\n- print(df.dtypes) # 각각의 컬럼 데이타타입\n- print(df.info()) # df.dtypes 비슷\n- print(df.info) # 전체적인 내용을???\n- print(df.head())\n- print(df.tail())\n'

# %% [markdown]
# ### * 인사이트를 도출하여 정보를 추출하고 시각화

# %%
# 대통령 리스트의 정당(Political Party)를 분석
df['Political Party']
# Out:
# 0                      None
# 1                Federalist
# 2     Democratic-Republican
# 3     Democratic-Republican
# 4     Democratic-Republican
# 5     Democratic-Republican
# 6                  Democrat
# 7                  Democrat
# 8                      Whig
# 9                  Democrat
# 10                     Whig
# 11                 Democrat
# 12                 Democrat
# 13               Republican
# 14               Republican
# 15               Republican
# 16               Republican
# 17                 Democrat
# 18               Republican
# 19                 Democrat
# 20               Republican
# 21               Republican
# 22                 Democrat
# 23               Republican
# 24               Republican
# 25                 Democrat
# 26               Republican
# 27                 Democrat
# 28               Republican
# 29                 Democrat
# 30               Republican
# 31               Republican
# 32                 Democrat
# ...

# %%
df['Political Party'].value_counts()
# Out:
# Republican               14
# Democrat                 13
# Democratic-Republican     4
# Whig                      2
# None                      1
# Federalist                1
# Name: Political Party, dtype: int64

# %%
# %matplotlib inline   
# 이 노트북 페이지에서 그래프 보이도록

# %%
pp = df['Political Party']
print(type(pp))
pp.value_counts().plot()

# %%
# ?pp.plot

# 후추에 그래프 제공하는 라이브러리들과 함수도 동일하고 엄청 헷갈린다

# %%
pp.value_counts().plot(kind='pie');

# %%
pp.value_counts().plot(kind='bar');

# %%
fromState  = df['State elected from']
fromState
# Out:
# 0          Virginia
# 1     Massachusetts
# 2          Virginia
# 3          Virginia
# 4          Virginia
# 5     Massachusetts
# 6         Tennessee
# 7          New York
# 8              Ohio
# 9         Tennessee
# 10        Louisiana
# 11    New Hampshire
# 12     Pennsylvania
# 13         Illinois
# 14         Illinois
# 15             Ohio
# 16             Ohio
# 17         New York
# 18          Indiana
# 19         New York
# 20             Ohio
# 21             Ohio
# 22       New Jersey
# 23             Ohio
# 24       California
# 25         New York
# 26         New York
# 27    Massachusetts
# 28         New York
# 29          Georgia
# 30       California
# 31            Texas
# 32         Arkansas
# 33            Texas
# 34         Illinois
# Name: State elected from, dtype: object

# %%
fromState.value_counts().plot();

# %%
# [참고] 웹에서 제공하는 데이타를 다운로드하기 

import urllib.request as req

local = './data/president/presidents.xlsx'  # data폴더 밑에 president 폴더가 있어야 한다
url = 'http://qrc.depaul.edu/excel_files/presidents.xlsx'
req.urlretrieve(url,local)
print('다운로드 완료')
# Out:
# 다운로드 완료
